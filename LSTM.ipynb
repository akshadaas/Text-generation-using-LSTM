# %%
import pandas as pd
import os
import string
import numpy as np

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import np_utils as ku
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.models import Sequential

# %%
path = r"Data/New york news headlines"
all_headlines =[]
for file in os.listdir(path):
    if 'Articles' in file:
        f = pd.read_csv(path + '//'+file)
        all_headlines.extend(list(f.headline.values))
        break
all_headlines = [h for h in all_headlines if h != "Unknown"]

# %%
def clean_text(txt):
    txt = "".join(v for v in txt if v not in string.punctuation).lower()
    #txt = txt.encode("utf8").decode("ascii",'ignore')
    return txt 

corpus = [clean_text(x) for x in all_headlines]
corpus[:10]
# Out:
# ['finding an expansive view  of a forgotten people in niger',
#  'and now  the dreaded trump curse',
#  'venezuela’s descent into dictatorship',
#  'stain permeates basketball blue blood',
#  'taking things for granted',
#  'the caged beast awakens',
#  'an everunfolding story',
#  'o’reilly thrives as settlements add up',
#  'mouse infestation',
#  'divide in gop now threatens trump tax plan']

# %%
tokenizer = Tokenizer()
def get_sequence_of_tokens(corpus):
    tokenizer.fit_on_texts(corpus)
    total_words = len(tokenizer.word_index) + 1
    #print(total_words)
    input_sequences = []
    for line in corpus:
        token_list = tokenizer.texts_to_sequences([line])[0]
        #print(line,token_list)
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
    return input_sequences, total_words
    
inp_sequences, total_words = get_sequence_of_tokens(corpus)

# %%
def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))
    #print(input_sequences)
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = ku.to_categorical(label, num_classes=total_words)
    return predictors, label, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(inp_sequences)

# %%
def create_model(max_sequence_len, total_words):
    input_len = max_sequence_len - 1
    model = Sequential()
    
    # Add Input Embedding Layer
    model.add(Embedding(total_words, 10, input_length=input_len))
    
    # Add Hidden Layer 1 - LSTM Layer
    model.add(LSTM(100))
    model.add(Dropout(0.1))
    
    # Add Output Layer
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    return model

model = create_model(max_sequence_len, total_words)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 10)            24830
#
#  lstm (LSTM)                 (None, 100)               44400
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 2483)              250783
#
# =================================================================
# Total params: 320,013
# Trainable params: 320,013
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(predictors, label, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 151/151 - 8s - loss: 7.4274 - 8s/epoch - 51ms/step
# Epoch 2/100
# 151/151 - 3s - loss: 6.9442 - 3s/epoch - 21ms/step
# Epoch 3/100
# 151/151 - 3s - loss: 6.8233 - 3s/epoch - 21ms/step
# Epoch 4/100
# 151/151 - 3s - loss: 6.7426 - 3s/epoch - 20ms/step
# Epoch 5/100
# 151/151 - 3s - loss: 6.6712 - 3s/epoch - 21ms/step
# Epoch 6/100
# 151/151 - 3s - loss: 6.5929 - 3s/epoch - 20ms/step
# Epoch 7/100
# 151/151 - 3s - loss: 6.5349 - 3s/epoch - 20ms/step
# Epoch 8/100
# 151/151 - 3s - loss: 6.4206 - 3s/epoch - 20ms/step
# Epoch 9/100
# 151/151 - 3s - loss: 6.3299 - 3s/epoch - 20ms/step
# Epoch 10/100
# 151/151 - 3s - loss: 6.2353 - 3s/epoch - 20ms/step
# Epoch 11/100
# 151/151 - 3s - loss: 6.1467 - 3s/epoch - 19ms/step
# Epoch 12/100
# 151/151 - 3s - loss: 6.0574 - 3s/epoch - 20ms/step
# Epoch 13/100
# 151/151 - 3s - loss: 5.9658 - 3s/epoch - 20ms/step
# Epoch 14/100
# 151/151 - 3s - loss: 5.8763 - 3s/epoch - 20ms/step
# Epoch 15/100
# 151/151 - 3s - loss: 5.7862 - 3s/epoch - 20ms/step
# Epoch 16/100
# 151/151 - 3s - loss: 5.6976 - 3s/epoch - 20ms/step
# Epoch 17/100
# 151/151 - 3s - loss: 5.6075 - 3s/epoch - 20ms/step
# Epoch 18/100
# 151/151 - 3s - loss: 5.5189 - 3s/epoch - 21ms/step
# Epoch 19/100
# 151/151 - 3s - loss: 5.4331 - 3s/epoch - 22ms/step
# Epoch 20/100
# 151/151 - 3s - loss: 5.3490 - 3s/epoch - 21ms/step
# Epoch 21/100
# 151/151 - 3s - loss: 5.2647 - 3s/epoch - 21ms/step
# Epoch 22/100
# 151/151 - 3s - loss: 5.1843 - 3s/epoch - 20ms/step
# Epoch 23/100
# 151/151 - 3s - loss: 5.1071 - 3s/epoch - 20ms/step
# Epoch 24/100
# 151/151 - 3s - loss: 5.0243 - 3s/epoch - 20ms/step
# Epoch 25/100
# 151/151 - 3s - loss: 4.9443 - 3s/epoch - 20ms/step
# Epoch 26/100
# 151/151 - 3s - loss: 4.8652 - 3s/epoch - 20ms/step
# Epoch 27/100
# 151/151 - 3s - loss: 4.7886 - 3s/epoch - 20ms/step
# Epoch 28/100
# 151/151 - 3s - loss: 4.7124 - 3s/epoch - 21ms/step
# Epoch 29/100
# 151/151 - 3s - loss: 4.6340 - 3s/epoch - 20ms/step
# Epoch 30/100
# 151/151 - 3s - loss: 4.5652 - 3s/epoch - 20ms/step
# Epoch 31/100
# 151/151 - 3s - loss: 4.4876 - 3s/epoch - 20ms/step
# Epoch 32/100
# 151/151 - 3s - loss: 4.4167 - 3s/epoch - 20ms/step
# Epoch 33/100
# 151/151 - 3s - loss: 4.3433 - 3s/epoch - 19ms/step
# Epoch 34/100
# 151/151 - 3s - loss: 4.2734 - 3s/epoch - 21ms/step
# Epoch 35/100
# 151/151 - 3s - loss: 4.2051 - 3s/epoch - 20ms/step
# Epoch 36/100
# 151/151 - 3s - loss: 4.1318 - 3s/epoch - 20ms/step
# Epoch 37/100
# 151/151 - 3s - loss: 4.0587 - 3s/epoch - 20ms/step
# Epoch 38/100
# 151/151 - 3s - loss: 3.9871 - 3s/epoch - 22ms/step
# Epoch 39/100
# 151/151 - 3s - loss: 3.9308 - 3s/epoch - 22ms/step
# Epoch 40/100
# 151/151 - 3s - loss: 3.8588 - 3s/epoch - 22ms/step
# Epoch 41/100
# 151/151 - 3s - loss: 3.7935 - 3s/epoch - 21ms/step
# Epoch 42/100
# 151/151 - 3s - loss: 3.7256 - 3s/epoch - 21ms/step
# Epoch 43/100
# 151/151 - 3s - loss: 3.6658 - 3s/epoch - 20ms/step
# Epoch 44/100
# 151/151 - 3s - loss: 3.6081 - 3s/epoch - 20ms/step
# Epoch 45/100
# 151/151 - 3s - loss: 3.5391 - 3s/epoch - 20ms/step
# Epoch 46/100
# 151/151 - 3s - loss: 3.4878 - 3s/epoch - 20ms/step
# Epoch 47/100
# 151/151 - 3s - loss: 3.4300 - 3s/epoch - 20ms/step
# Epoch 48/100
# 151/151 - 3s - loss: 3.3732 - 3s/epoch - 20ms/step
# Epoch 49/100
# 151/151 - 3s - loss: 3.3226 - 3s/epoch - 20ms/step
# Epoch 50/100
# 151/151 - 3s - loss: 3.2729 - 3s/epoch - 20ms/step
# Epoch 51/100
# 151/151 - 3s - loss: 3.2139 - 3s/epoch - 20ms/step
# Epoch 52/100
# 151/151 - 3s - loss: 3.1573 - 3s/epoch - 20ms/step
# Epoch 53/100
# 151/151 - 3s - loss: 3.1131 - 3s/epoch - 20ms/step
# Epoch 54/100
# 151/151 - 3s - loss: 3.0516 - 3s/epoch - 20ms/step
# Epoch 55/100
# 151/151 - 3s - loss: 2.9994 - 3s/epoch - 21ms/step
# Epoch 56/100
# 151/151 - 3s - loss: 2.9644 - 3s/epoch - 20ms/step
# Epoch 57/100
# 151/151 - 3s - loss: 2.9176 - 3s/epoch - 20ms/step
# Epoch 58/100
# 151/151 - 3s - loss: 2.8656 - 3s/epoch - 22ms/step
# Epoch 59/100
# 151/151 - 3s - loss: 2.8247 - 3s/epoch - 22ms/step
# Epoch 60/100
# 151/151 - 3s - loss: 2.7806 - 3s/epoch - 21ms/step
# Epoch 61/100
# 151/151 - 3s - loss: 2.7381 - 3s/epoch - 20ms/step
# Epoch 62/100
# 151/151 - 3s - loss: 2.7049 - 3s/epoch - 22ms/step
# Epoch 63/100
# 151/151 - 3s - loss: 2.6481 - 3s/epoch - 20ms/step
# Epoch 64/100
# 151/151 - 3s - loss: 2.6203 - 3s/epoch - 20ms/step
# Epoch 65/100
# 151/151 - 3s - loss: 2.5743 - 3s/epoch - 20ms/step
# Epoch 66/100
# 151/151 - 3s - loss: 2.5290 - 3s/epoch - 22ms/step
# Epoch 67/100
# 151/151 - 3s - loss: 2.4956 - 3s/epoch - 23ms/step
# Epoch 68/100
# 151/151 - 3s - loss: 2.4556 - 3s/epoch - 20ms/step
# Epoch 69/100
# 151/151 - 3s - loss: 2.4207 - 3s/epoch - 20ms/step
# Epoch 70/100
# 151/151 - 3s - loss: 2.4022 - 3s/epoch - 20ms/step
# Epoch 71/100
# 151/151 - 3s - loss: 2.3647 - 3s/epoch - 21ms/step
# Epoch 72/100
# 151/151 - 3s - loss: 2.3238 - 3s/epoch - 21ms/step
# Epoch 73/100
# 151/151 - 3s - loss: 2.2887 - 3s/epoch - 20ms/step
# Epoch 74/100
# 151/151 - 3s - loss: 2.2588 - 3s/epoch - 20ms/step
# Epoch 75/100
# 151/151 - 3s - loss: 2.2285 - 3s/epoch - 20ms/step
# Epoch 76/100
# 151/151 - 3s - loss: 2.1992 - 3s/epoch - 20ms/step
# Epoch 77/100
# 151/151 - 3s - loss: 2.1613 - 3s/epoch - 21ms/step
# Epoch 78/100
# 151/151 - 3s - loss: 2.1374 - 3s/epoch - 22ms/step
# Epoch 79/100
# 151/151 - 3s - loss: 2.1012 - 3s/epoch - 22ms/step
# Epoch 80/100
# 151/151 - 3s - loss: 2.0785 - 3s/epoch - 20ms/step
# Epoch 81/100
# 151/151 - 3s - loss: 2.0301 - 3s/epoch - 20ms/step
# Epoch 82/100
# 151/151 - 3s - loss: 2.0199 - 3s/epoch - 20ms/step
# Epoch 83/100
# 151/151 - 3s - loss: 1.9899 - 3s/epoch - 20ms/step
# Epoch 84/100
# 151/151 - 3s - loss: 1.9624 - 3s/epoch - 20ms/step
# Epoch 85/100
# 151/151 - 3s - loss: 1.9381 - 3s/epoch - 20ms/step
# Epoch 86/100
# 151/151 - 3s - loss: 1.9100 - 3s/epoch - 20ms/step
# Epoch 87/100
# 151/151 - 3s - loss: 1.8809 - 3s/epoch - 20ms/step
# Epoch 88/100
# 151/151 - 3s - loss: 1.8583 - 3s/epoch - 20ms/step
# Epoch 89/100
# 151/151 - 3s - loss: 1.8377 - 3s/epoch - 20ms/step
# Epoch 90/100
# 151/151 - 3s - loss: 1.8158 - 3s/epoch - 20ms/step
# Epoch 91/100
# 151/151 - 3s - loss: 1.7825 - 3s/epoch - 20ms/step
# Epoch 92/100
# 151/151 - 3s - loss: 1.7587 - 3s/epoch - 20ms/step
# Epoch 93/100
# 151/151 - 3s - loss: 1.7487 - 3s/epoch - 20ms/step
# Epoch 94/100
# 151/151 - 3s - loss: 1.7235 - 3s/epoch - 19ms/step
# Epoch 95/100
# 151/151 - 3s - loss: 1.6934 - 3s/epoch - 20ms/step
# Epoch 96/100
# 151/151 - 3s - loss: 1.6634 - 3s/epoch - 20ms/step
# Epoch 97/100
# 151/151 - 3s - loss: 1.6543 - 3s/epoch - 22ms/step
# Epoch 98/100
# 151/151 - 3s - loss: 1.6304 - 3s/epoch - 22ms/step
# Epoch 99/100
# 151/151 - 3s - loss: 1.6081 - 3s/epoch - 22ms/step
# Epoch 100/100
# 151/151 - 3s - loss: 1.5840 - 3s/epoch - 20ms/step

# %%
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        #predicted = model.predict_classes(token_list, verbose=0)
        predict_x=model.predict(token_list) 
        predicted=np.argmax(predict_x,axis=1)
        output_word = ""
        for word,index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " "+output_word
    return seed_text.title()

# %%
print (generate_text("united states", 10, model, max_sequence_len))
print (generate_text("preident trump", 6, model, max_sequence_len))
print (generate_text("donald trump", 4, model, max_sequence_len))
print (generate_text("india and china", 4, model, max_sequence_len))
print (generate_text("new york", 4, model, max_sequence_len))
print (generate_text("science and technology", 5, model, max_sequence_len))
# Out:
# United States Up A Grizzled Rivalry Gets A Freshfaced Makeover Too Future
# Preident Trump May Sign Orders That Could Expand
# Donald Trump A ‘Criminal’ Book For
# India And China Players A Uniforms And
# New York Today A Belated Budget
# Science And Technology A Tribal Identity Voting Against
